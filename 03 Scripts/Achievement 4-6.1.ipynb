# %% [markdown]
# ## Importing Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Importing Data Sets

# %%
path=r'C:\Users\sasze\Documents\Careerfoundry Data Analytics\Achievement 4'

# %%
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'order_products__prior.csv'), index_col = False)

# %%
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_cleaned.csv'), index_col = False)

# %% [markdown]
# ## Merged Data

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', how = 'outer', indicator = True)

# %%
df_merged_large
# Out:
#           Unnamed: 0  Unnamed: 0.1  order_id  user_id  order_number  \
# 0                  0             0   2539329        1             1
# 1                  0             0   2539329        1             1
# 2                  0             0   2539329        1             1
# 3                  0             0   2539329        1             1
# 4                  0             0   2539329        1             1
# ...              ...           ...       ...      ...           ...
# 32640693     3421081       3421081   2977660   206209            13
# 32640694     3421081       3421081   2977660   206209            13
# 32640695     3421081       3421081   2977660   206209            13
# 32640696     3421081       3421081   2977660   206209            13
# 32640697     3421082       3421082    272231   206209            14
#
#           orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                          2                  8                     NaN
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# left_only       206209
# right_only           0
# Name: _merge, dtype: int64

# %%
df_merged_large.to_pickle(r'C:\Users\sasze\Documents\Careerfoundry Data Analytics\Achievement 4\02 Data\Prepared Data\orders_products_combined.pkl')
